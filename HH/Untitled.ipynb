# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('credit_data.csv')

# %%
data.head()
# Out:
#    Index  Age     Sex  Job Housing Saving accounts Checking account  \
# 0      0   67    male    2     own             NaN           little
# 1      1   22  female    2     own          little         moderate
# 2      2   49    male    1     own          little              NaN
# 3      3   45    male    2    free          little           little
# 4      4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose
# 0           1169         6             radio/TV
# 1           5951        48             radio/TV
# 2           2096        12            education
# 3           7882        42  furniture/equipment
# 4           4870        24                  car

# %%
data.set_index('Index',inplace=True)

# %%
data.head()
# Out:
#        Age     Sex  Job Housing Saving accounts Checking account  \
# Index
# 0       67    male    2     own             NaN           little
# 1       22  female    2     own          little         moderate
# 2       49    male    1     own          little              NaN
# 3       45    male    2    free          little           little
# 4       53    male    2    free          little           little
#
#        Credit amount  Duration              Purpose
# Index
# 0               1169         6             radio/TV
# 1               5951        48             radio/TV
# 2               2096        12            education
# 3               7882        42  furniture/equipment
# 4               4870        24                  car

# %%
data[:5]
# Out:
#        Age     Sex  Job Housing Saving accounts Checking account  \
# Index
# 0       67    male    2     own             NaN           little
# 1       22  female    2     own          little         moderate
# 2       49    male    1     own          little              NaN
# 3       45    male    2    free          little           little
# 4       53    male    2    free          little           little
#
#        Credit amount  Duration              Purpose
# Index
# 0               1169         6             radio/TV
# 1               5951        48             radio/TV
# 2               2096        12            education
# 3               7882        42  furniture/equipment
# 4               4870        24                  car

# %%
data = pd.DataFrame(data)

# %%
# Out:
# Index
# 0        male
# 1      female
# 2        male
# 3        male
# 4        male
# 5        male
# 6        male
# 7        male
# 8        male
# 9        male
# 10     female
# 11     female
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17       male
# 18     female
# 19       male
# 20       male
# 21       male
# 22       male
# 23       male
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29       male
#         ...
# 970      male
# 971      male
# 972    female
# 973      male
# 974    female
# 975    female
# 976    female
# 977      male
# 978      male
# 979      male
# 980      male
# 981      male
# 982    female
# 983      male
# 984      male
# 985    female
# 986      male
# 987    female
# 988      male
# 989      male
# 990      male
# 991      male
# 992      male
# 993      male
# 994      male
# 995    female
# 996      male
# 997      male
# 998      male
# 999      male
# ...

# %%
import urllib

# %%
user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

url = "https://yts.am/api/v2/list_movies.json"
headers={'User-Agent':user_agent,} 
request=urllib.request.Request(url,None,headers)
response = urllib.request.urlopen(request)

# %%
data1 = response.read().decode('utf-8')

# %%
data2 = eval(data1)

# %%
data2 = data2['data']['movies']
data2
# Out:
# [{'id': 8072,
#   'url': 'https:\\/\\/yts.am\\/movie\\/peeping-tom-1960',
#   'imdb_code': 'tt0054167',
#   'title': 'Peeping Tom',
#   'title_english': 'Peeping Tom',
#   'title_long': 'Peeping Tom (1960)',
#   'slug': 'peeping-tom-1960',
#   'year': 1960,
#   'rating': 7.7,
#   'runtime': 101,
#   'genres': ['Drama', 'Horror', 'Thriller'],
# ...

# %%
data3 = pd.DataFrame(data2)

# %%
data3.head(3)
# Out:
#                                     background_image  \
# 0  https:\/\/yts.am\/assets\/images\/movies\/peep...
# 1  https:\/\/yts.am\/assets\/images\/movies\/deep...
# 2  https:\/\/yts.am\/assets\/images\/movies\/the_...
#
#                            background_image_original        date_uploaded  \
# 0  https:\/\/yts.am\/assets\/images\/movies\/peep...  2018-06-19 08:24:53
# 1  https:\/\/yts.am\/assets\/images\/movies\/deep...  2018-06-19 04:57:54
# 2  https:\/\/yts.am\/assets\/images\/movies\/the_...  2018-06-19 07:46:32
#
#    date_uploaded_unix                                   description_full  \
# 0          1529389493  Mark Lewis, works as a focus puller in a Briti...
# 1          1529377074  A psychic who can read minds picks up the thou...
# 2          1529387192  The O'Neills lived happily in their house in t...
#
#                         genres    id  imdb_code language  \
# 0    [Drama, Horror, Thriller]  8072  tt0054167  English
# ...

# %%
data3.columns
# Out:
# Index(['background_image', 'background_image_original', 'date_uploaded',
#        'date_uploaded_unix', 'description_full', 'genres', 'id', 'imdb_code',
#        'language', 'large_cover_image', 'medium_cover_image', 'mpa_rating',
#        'rating', 'runtime', 'slug', 'small_cover_image', 'state', 'summary',
#        'synopsis', 'title', 'title_english', 'title_long', 'torrents', 'url',
#        'year', 'yt_trailer_code'],
#       dtype='object')

# %%
data3 = data3.drop(['background_image', 'background_image_original', 'date_uploaded',
       'date_uploaded_unix', 'description_full', 'genres', 'large_cover_image', 'medium_cover_image','runtime', 'slug', 'small_cover_image', 'state', 'summary',
       'synopsis', 'title_english', 'title_long', 'torrents', 'url', 'yt_trailer_code'
        ], axis=1)

# %%
data3
# Out:
#       id  imdb_code language mpa_rating  rating                        title  \
# 0   8072  tt0054167  English                7.7                  Peeping Tom
# 1   8071  tt0073582  English                7.7                     Deep Red
# 2   8070  tt1496005  English                6.6                     The Tree
# 3   8069  tt0454084  English      PG-13     6.1                 Blind Dating
# 4   8068  tt4538916  English      PG-13     6.7            Finding Your Feet
# 5   8067  tt7167658  English      PG-13     0.0        The Death of Superman
# 6   8066  tt5619332  English      PG-13     5.5            Life of the Party
# 7   8065  tt2231461  English      PG-13     6.5                      Rampage
# 8   8064  tt0088258  English                8.0           This Is Spinal Tap
# 9   8063  tt0045339  English                7.2        The World in His Arms
# 10  8062  tt1677720  English      PG-13     7.7             Ready Player One
# ...
