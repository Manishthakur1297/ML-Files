# %%
import numpy as np
import pandas as pd

# %%
import quandl

# %%
df = quandl.get('WIKI/GOOGL')

# %%
df
# Out:
#                 Open     High      Low     Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19   100.010   104.06    95.96   100.335  44659000.0          0.0
# 2004-08-20   101.010   109.08   100.50   108.310  22834300.0          0.0
# 2004-08-23   110.760   113.48   109.05   109.400  18256100.0          0.0
# 2004-08-24   111.240   111.60   103.57   104.870  15247300.0          0.0
# 2004-08-25   104.760   108.00   103.88   106.000   9188600.0          0.0
# 2004-08-26   104.950   107.95   104.66   107.910   7094800.0          0.0
# 2004-08-27   108.100   108.62   105.69   106.150   6211700.0          0.0
# 2004-08-30   105.280   105.49   102.01   102.010   5196700.0          0.0
# 2004-08-31   102.320   103.71   102.16   102.370   4917800.0          0.0
# 2004-09-01   102.700   102.97    99.67   100.250   9138200.0          0.0
# 2004-09-02    99.090   102.37    98.94   101.510  15118600.0          0.0
# 2004-09-03   100.950   101.74    99.32   100.010   5152400.0          0.0
# ...

# %%
df.head()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19  100.01  104.06   95.96  100.335  44659000.0          0.0
# 2004-08-20  101.01  109.08  100.50  108.310  22834300.0          0.0
# 2004-08-23  110.76  113.48  109.05  109.400  18256100.0          0.0
# 2004-08-24  111.24  111.60  103.57  104.870  15247300.0          0.0
# 2004-08-25  104.76  108.00  103.88  106.000   9188600.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19          1.0  50.159839  52.191109  48.128568   50.322842
# 2004-08-20          1.0  50.661387  54.708881  50.405597   54.322689
# 2004-08-23          1.0  55.551482  56.915693  54.693835   54.869377
# 2004-08-24          1.0  55.792225  55.972783  51.945350   52.597363
# 2004-08-25          1.0  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# ...

# %%
df1 = df.index

# %%
df1
# Out:
# DatetimeIndex(['2004-08-19', '2004-08-20', '2004-08-23', '2004-08-24',
#                '2004-08-25', '2004-08-26', '2004-08-27', '2004-08-30',
#                '2004-08-31', '2004-09-01',
#                ...
#                '2018-03-14', '2018-03-15', '2018-03-16', '2018-03-19',
#                '2018-03-20', '2018-03-21', '2018-03-22', '2018-03-23',
#                '2018-03-26', '2018-03-27'],
#               dtype='datetime64[ns]', name='Date', length=3424, freq=None)

# %%
######

# %%
pd.date_range('2004-08-19',periods=22)
# Out:
# DatetimeIndex(['2004-08-19', '2004-08-20', '2004-08-21', '2004-08-22',
#                '2004-08-23', '2004-08-24', '2004-08-25', '2004-08-26',
#                '2004-08-27', '2004-08-28', '2004-08-29', '2004-08-30',
#                '2004-08-31', '2004-09-01', '2004-09-02', '2004-09-03',
#                '2004-09-04', '2004-09-05', '2004-09-06', '2004-09-07',
#                '2004-09-08', '2004-09-09'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.head()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19  100.01  104.06   95.96  100.335  44659000.0          0.0
# 2004-08-20  101.01  109.08  100.50  108.310  22834300.0          0.0
# 2004-08-23  110.76  113.48  109.05  109.400  18256100.0          0.0
# 2004-08-24  111.24  111.60  103.57  104.870  15247300.0          0.0
# 2004-08-25  104.76  108.00  103.88  106.000   9188600.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19          1.0  50.159839  52.191109  48.128568   50.322842
# 2004-08-20          1.0  50.661387  54.708881  50.405597   54.322689
# 2004-08-23          1.0  55.551482  56.915693  54.693835   54.869377
# 2004-08-24          1.0  55.792225  55.972783  51.945350   52.597363
# 2004-08-25          1.0  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# ...

# %%
df['2004-08-19':'2004-08-29']
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19  100.01  104.06   95.96  100.335  44659000.0          0.0
# 2004-08-20  101.01  109.08  100.50  108.310  22834300.0          0.0
# 2004-08-23  110.76  113.48  109.05  109.400  18256100.0          0.0
# 2004-08-24  111.24  111.60  103.57  104.870  15247300.0          0.0
# 2004-08-25  104.76  108.00  103.88  106.000   9188600.0          0.0
# 2004-08-26  104.95  107.95  104.66  107.910   7094800.0          0.0
# 2004-08-27  108.10  108.62  105.69  106.150   6211700.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19          1.0  50.159839  52.191109  48.128568   50.322842
# 2004-08-20          1.0  50.661387  54.708881  50.405597   54.322689
# 2004-08-23          1.0  55.551482  56.915693  54.693835   54.869377
# 2004-08-24          1.0  55.792225  55.972783  51.945350   52.597363
# ...

# %%
df['2004-08-19':'2004-08-29'].Close.mean()
# Out:
# 106.1392857142857

# %%
# %matplotlib inline

# %%
df['2004-08-19':'2004-08-29'].Volume.plot(kind='bar')

# %%
df['2004-08-19':'2004-08-29'].Volume.plot(kind='pie')

# %%
p=pd.Period('2004',freq='H')
p
# Out:
# Period('2004-01-01 00:00', 'H')

# %%
p+1
# Out:
# Period('2004-01-01 01:00', 'H')

# %%
p=pd.Period('2004',freq='Q')
p
# Out:
# Period('2004Q1', 'Q-DEC')

# %%
p+5
# Out:
# Period('2005Q2', 'Q-DEC')

# %%
import requests

# %%
import urllib.request as ur

# %%
data = ur.urlopen('https://www.googleapis.com/youtube/v3/search?key=AIzaSyCuNPXBzrHf0l9MF-jkY8d_xoHRekzputw&channelId=UCsSZyyGKf9FdpqDmynjVBcA&part=snippet,id&order=date&maxResults=50')
data1 = data.read().decode('utf-8')

# %%
data1
# Out:
# '{\n "kind": "youtube#searchListResponse",\n "etag": "\\"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/mamF7NkPyjSPJfwJxbvde_rHI88\\"",\n "nextPageToken": "CDIQAA",\n "regionCode": "IN",\n "pageInfo": {\n  "totalResults": 152,\n  "resultsPerPage": 50\n },\n "items": [\n  {\n   "kind": "youtube#searchResult",\n   "etag": "\\"DuHzAJ-eQIiCIp7p4ldoVcVAOeY/9pqKwnPu7yEFPhrofVa5lXGilUI\\"",\n   "id": {\n    "kind": "youtube#video",\n    "videoId": "_racwoshCHU"\n   },\n   "snippet": {\n    "publishedAt": "2018-06-18T08:11:53.000Z",\n    "channelId": "UCsSZyyGKf9FdpqDmynjVBcA",\n    "title": "Work Submissions-  School | College | Office",\n    "description": "Download and Join me on LIKE App, it has #ShapingMagic contest going on where you can create video and win iPhone X, $10000 or many more exciting ...",\n    "thumbnails": {\n     "default": {\n      "url": "https://i.ytimg.com/vi/_racwoshCHU/default.jpg",\n      "width": 120,\n      "height": 90\n     },\n     "medium": {\n      "url": "https://i.ytimg.c
# ...

# %%
data1['kind']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-3830a77ee9ef> in <module>()
# ----> 1 data1['kind']
#
# TypeError: string indices must be integers

# %%
from sklearn.datasets import load_iris

# %%
from sklearn import cluster

# %%
# clf = cluster.KMeans(n_clusters=3)
# clf.fit(X)
# clf.predict(0)

# %%
data =load_iris()

# %%
data = data['data']

# %%
x = data[:,:2]

# %%
y = data[:,2:]

# %%
x[:5]
# Out:
# array([[5.1, 3.5],
#        [4.9, 3. ],
#        [4.7, 3.2],
#        [4.6, 3.1],
#        [5. , 3.6]])

# %%
y[:5]
# Out:
# array([[1.4, 0.2],
#        [1.4, 0.2],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.4, 0.2]])

# %%
# features = []#np.array([])
# for k in Patel_LW:
#     features = np.append(features,np.sum(k))

# %%
clf = cluster.KMeans(n_clusters=3)
clf.fit(x)
# clf.predict(0)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
clf.c
